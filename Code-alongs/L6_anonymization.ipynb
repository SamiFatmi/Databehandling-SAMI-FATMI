# %%
import hashlib as hl


secret = "gore_bord@gmail.com".encode()  # utf-8 encoded version
secret2 = "gore_bord1@gmail.com".encode()

print(secret)

secret_hash = hl.sha256(secret).hexdigest()
secret_hash2 = hl.sha256(secret2).hexdigest()

print(f"secret_hash : {secret_hash}")

secret_hash_same= hl.sha256("gore_bord@gmail.com".encode()).hexdigest()

print(f"secret_hash_same : {secret_hash_same}")
print(f"secret_hash2 : {secret_hash2}")

secret_hash == secret_hash_same
# Out:
# b'gore_bord@gmail.com'
# secret_hash : 7d6d9a849ccc7f5febe065ebe3b4f39558fc96ef865e02333dd7b7426ff0c057
# secret_hash_same : 7d6d9a849ccc7f5febe065ebe3b4f39558fc96ef865e02333dd7b7426ff0c057
# secret_hash2 : 0290afd54f254c13b9b8c0d6037e4aaf26c65bb025b1815f2ef8a81f3042d7dc
# True

# %% [markdown]
# # Exemple with Pandas

# %%
import pandas as pd 

bank = pd.read_csv("Data/BankChurners.csv")

bank.head(3)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# 1              44  ...        8256.0                  864           7392.0
# 2              36  ...        3418.0                    0           3418.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# ...

# %%
bank["CLIENTNUM"] = bank["CLIENTNUM"].astype(str)

bank["CLIENTNUM"].head()
# Out:
# 0    768805383
# 1    818770008
# 2    713982108
# 3    769911858
# 4    709106358
# Name: CLIENTNUM, dtype: object

# %%
hash_series = bank["CLIENTNUM"].apply(lambda x: hl.sha256(x.encode()).hexdigest())

hash_series.head()
# Out:
# 0    c9bbef56f9d8292cb3cfa8ae91f9b9167390e6e4b514d5...
# 1    7996e2340d70489252370a5df035ec99381c8344cc3511...
# 2    6fb53dbc743724e086243b5bc288df62b4a6dc1b8bde92...
# 3    f86b86a1047317685f29c399059b199858685faf5ec6a8...
# 4    0d239470b0cb57e110cf60bc3865344ee2cdced6e3acdc...
# Name: CLIENTNUM, dtype: object

# %%
bank.insert(1,"Hashed client numbers",hash_series)

bank.head()
# Out:
#    CLIENTNUM                              Hashed client numbers  \
# 0  768805383  c9bbef56f9d8292cb3cfa8ae91f9b9167390e6e4b514d5...
# 1  818770008  7996e2340d70489252370a5df035ec99381c8344cc3511...
# 2  713982108  6fb53dbc743724e086243b5bc288df62b4a6dc1b8bde92...
# 3  769911858  f86b86a1047317685f29c399059b199858685faf5ec6a8...
# 4  709106358  0d239470b0cb57e110cf60bc3865344ee2cdced6e3acdc...
#
#       Attrition_Flag  Customer_Age Gender  Dependent_count Education_Level  \
# 0  Existing Customer            45      M                3     High School
# 1  Existing Customer            49      F                5        Graduate
# 2  Existing Customer            51      M                3        Graduate
# 3  Existing Customer            40      F                4     High School
# 4  Existing Customer            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  ...  Credit_Limit  \
# ...

# %%
bank = bank.drop(columns="CLIENTNUM")

bank.head()
# Out:
#                                Hashed client numbers     Attrition_Flag  \
# 0  c9bbef56f9d8292cb3cfa8ae91f9b9167390e6e4b514d5...  Existing Customer
# 1  7996e2340d70489252370a5df035ec99381c8344cc3511...  Existing Customer
# 2  6fb53dbc743724e086243b5bc288df62b4a6dc1b8bde92...  Existing Customer
# 3  f86b86a1047317685f29c399059b199858685faf5ec6a8...  Existing Customer
# 4  0d239470b0cb57e110cf60bc3865344ee2cdced6e3acdc...  Existing Customer
#
#    Customer_Age Gender  Dependent_count Education_Level Marital_Status  \
# 0            45      M                3     High School        Married
# 1            49      F                5        Graduate         Single
# 2            51      M                3        Graduate        Married
# 3            40      F                4     High School        Unknown
# 4            40      M                3      Uneducated        Married
#
#   Income_Category Card_Category  Months_on_book  ...  Credit_Limit  \
# ...

# %%
athlete = pd.read_excel(../)
