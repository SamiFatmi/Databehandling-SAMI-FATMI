# %% [markdown]
# # Missing data and aggregation
# - in real world, there will be missing data and unwanted disturbance data

# %% [markdown]
# ## Setup

# %%
import numpy as np 
import pandas as pd


np.random.seed(42)
n=10

#create dummy data 

random_matrix = np.random.randint(1,10,[n,n])
index = np.random.choice(random_matrix.size,10,replace=False)
print(index)

random_matrix= random_matrix*1.0
random_matrix.ravel()[index] = None 

random_matrix
# Out:
# [ 9 84  6 39 92 33 68 85 20 17]
# array([[ 7.,  4.,  8.,  5.,  7.,  3., nan,  8.,  5., nan],
#        [ 8.,  8.,  3.,  6.,  5.,  2.,  8., nan,  2.,  5.],
#        [nan,  6.,  9.,  1.,  3.,  7.,  4.,  9.,  3.,  5.],
#        [ 3.,  7.,  5., nan,  7.,  2.,  4.,  9.,  2., nan],
#        [ 5.,  2.,  4.,  7.,  8.,  3.,  1.,  4.,  2.,  8.],
#        [ 4.,  2.,  6.,  6.,  4.,  6.,  2.,  2.,  4.,  8.],
#        [ 7.,  9.,  8.,  5.,  2.,  5.,  8.,  9., nan,  1.],
#        [ 9.,  7.,  9.,  8.,  1.,  8.,  8.,  3.,  1.,  8.],
#        [ 3.,  3.,  1.,  5., nan, nan,  7.,  9.,  8.,  2.],
#        [ 1.,  7., nan,  8.,  5.,  3.,  8.,  6.,  3.,  1.]])

# %%
scores = pd.DataFrame(random_matrix, 
                        index =[ f"Player {i}" for i in range(1,n+1)],
                        columns= [ f"Round {i}" for i in range (1, n+1)])

scores
# Out:
#            Round 1  Round 2  Round 3  Round 4  Round 5  Round 6  Round 7  \
# Player 1       7.0      4.0      8.0      5.0      7.0      3.0      NaN
# Player 2       8.0      8.0      3.0      6.0      5.0      2.0      8.0
# Player 3       NaN      6.0      9.0      1.0      3.0      7.0      4.0
# Player 4       3.0      7.0      5.0      NaN      7.0      2.0      4.0
# Player 5       5.0      2.0      4.0      7.0      8.0      3.0      1.0
# Player 6       4.0      2.0      6.0      6.0      4.0      6.0      2.0
# Player 7       7.0      9.0      8.0      5.0      2.0      5.0      8.0
# Player 8       9.0      7.0      9.0      8.0      1.0      8.0      8.0
# Player 9       3.0      3.0      1.0      5.0      NaN      NaN      7.0
# Player 10      1.0      7.0      NaN      8.0      5.0      3.0      8.0
#
#            Round 8  Round 9  Round 10
# Player 1       8.0      5.0       NaN
# Player 2       NaN      2.0       5.0
# Player 3       9.0      3.0       5.0
# ...

# %%
scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Player 1 to Player 10
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Round 1   9 non-null      float64
#  1   Round 2   10 non-null     float64
#  2   Round 3   9 non-null      float64
#  3   Round 4   9 non-null      float64
#  4   Round 5   9 non-null      float64
#  5   Round 6   9 non-null      float64
#  6   Round 7   9 non-null      float64
#  7   Round 8   9 non-null      float64
#  8   Round 9   9 non-null      float64
#  9   Round 10  8 non-null      float64
# dtypes: float64(10)
# memory usage: 880.0+ bytes

# %% [markdown]
# ## Missing value methods
# - isnull() - True if null
# - notnull() - True if not null
# - dropna() - drops an axis with nulls
# - fillna() - fills the null values with certain values

# %%
scores.isnull()
# Out:
#            Round 1  Round 2  Round 3  Round 4  Round 5  Round 6  Round 7  \
# Player 1     False    False    False    False    False    False     True
# Player 2     False    False    False    False    False    False    False
# Player 3      True    False    False    False    False    False    False
# Player 4     False    False    False     True    False    False    False
# Player 5     False    False    False    False    False    False    False
# Player 6     False    False    False    False    False    False    False
# Player 7     False    False    False    False    False    False    False
# Player 8     False    False    False    False    False    False    False
# Player 9     False    False    False    False     True     True    False
# Player 10    False    False     True    False    False    False    False
#
#            Round 8  Round 9  Round 10
# Player 1     False    False      True
# Player 2      True    False     False
# Player 3     False    False     False
# ...

# %%
scores.notnull()
# Out:
#            Round 1  Round 2  Round 3  Round 4  Round 5  Round 6  Round 7  \
# Player 1      True     True     True     True     True     True    False
# Player 2      True     True     True     True     True     True     True
# Player 3     False     True     True     True     True     True     True
# Player 4      True     True     True    False     True     True     True
# Player 5      True     True     True     True     True     True     True
# Player 6      True     True     True     True     True     True     True
# Player 7      True     True     True     True     True     True     True
# Player 8      True     True     True     True     True     True     True
# Player 9      True     True     True     True    False    False     True
# Player 10     True     True    False     True     True     True     True
#
#            Round 8  Round 9  Round 10
# Player 1      True     True     False
# Player 2     False     True      True
# Player 3      True     True      True
# ...

# %%
scores.dropna()
# Out:
#           Round 1  Round 2  Round 3  Round 4  Round 5  Round 6  Round 7  \
# Player 5      5.0      2.0      4.0      7.0      8.0      3.0      1.0
# Player 6      4.0      2.0      6.0      6.0      4.0      6.0      2.0
# Player 8      9.0      7.0      9.0      8.0      1.0      8.0      8.0
#
#           Round 8  Round 9  Round 10
# Player 5      4.0      2.0       8.0
# Player 6      2.0      4.0       8.0
# Player 8      3.0      1.0       8.0

# %%
scores.dropna(axis="columns")
# Out:
#            Round 2
# Player 1       4.0
# Player 2       8.0
# Player 3       6.0
# Player 4       7.0
# Player 5       2.0
# Player 6       2.0
# Player 7       9.0
# Player 8       7.0
# Player 9       3.0
# Player 10      7.0

# %%
# How to treat Nans depends on the situation. Many times you need to talk to domain experts. 

scores.fillna(0) # in this case it is reasonable to give 0 to missing values
# Out:
#            Round 1  Round 2  Round 3  Round 4  Round 5  Round 6  Round 7  \
# Player 1       7.0      4.0      8.0      5.0      7.0      3.0      0.0
# Player 2       8.0      8.0      3.0      6.0      5.0      2.0      8.0
# Player 3       0.0      6.0      9.0      1.0      3.0      7.0      4.0
# Player 4       3.0      7.0      5.0      0.0      7.0      2.0      4.0
# Player 5       5.0      2.0      4.0      7.0      8.0      3.0      1.0
# Player 6       4.0      2.0      6.0      6.0      4.0      6.0      2.0
# Player 7       7.0      9.0      8.0      5.0      2.0      5.0      8.0
# Player 8       9.0      7.0      9.0      8.0      1.0      8.0      8.0
# Player 9       3.0      3.0      1.0      5.0      0.0      0.0      7.0
# Player 10      1.0      7.0      0.0      8.0      5.0      3.0      8.0
#
#            Round 8  Round 9  Round 10
# Player 1       8.0      5.0       0.0
# Player 2       0.0      2.0       5.0
# Player 3       9.0      3.0       5.0
# ...

# %% [markdown]
# ## Missing value strategy
#
# Strategy depends on :
# - dataset size
# - valuable information (some rows, some columns)
# - percentage missing values
# - domain knowledge
# - missing values can impact
#     - data visualization
#     - arithmetic computations
#     - summary statistics
#     - machine learning algorithms

# %%
import seaborn as sns 

titanic = sns.load_dataset("titanic")

titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.histplot(data=titanic, x="age", kde=True, hue="sex")
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=titanic, x="age", kde=True, hue="sex", multiple="stack")
sns.set_theme()

# %%
len(titanic[titanic["sex"]=="male"])
# Out:
# 577

# %%
median_male_age = titanic.loc[titanic["sex"]=="male","age"].median()
median_female_age = titanic.loc[titanic["sex"]=="female","age"].median()

median_female_age , median_male_age
# Out:
# (27.0, 29.0)

# %%
titanic.loc[titanic["sex"] =="male","age"] =  titanic.loc[titanic["sex"]=="male" ,"age"].fillna(median_male_age)
titanic.loc[titanic["sex"]=="female" ,"age"] = titanic.loc[titanic["sex"]=="female" ,"age"].fillna(median_female_age)

titanic["age"].isnull().sum()
# Out:
# 0

# %%
sns.histplot(data=titanic, x="age", hue = "sex", kde=True, multiple="dodge", bins=50 )
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
# groupby

titanic.groupby("sex").median()
# Out:
#         survived  pclass   age  sibsp  parch  fare  adult_male  alone
# sex
# female       1.0     2.0  27.0    0.0    0.0  23.0         0.0    0.0
# male         0.0     3.0  29.0    0.0    0.0  10.5         1.0    1.0
